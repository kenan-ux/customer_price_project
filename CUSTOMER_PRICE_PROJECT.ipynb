# %%
import numpy as np
import pandas as pd
import os

# %%
df=pd.read_csv("C:\\Users\\kenan\\Downloads\\price.csv")

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df.shape
# Out:
# (2000, 8)

# %% [markdown]
# DATA CLEANING

# %%
df.info
# Out:
# <bound method DataFrame.info of       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %% [markdown]
# REMOVE NULL VALUES

# %%
df.drop(["Profession"],axis=1,inplace=True)

# %%
df.isnull()
# Out:
#       CustomerID  Gender    Age  Annual Income ($)  Spending Score (1-100)  \
# 0          False   False  False              False                   False
# 1          False   False  False              False                   False
# 2          False   False  False              False                   False
# 3          False   False  False              False                   False
# 4          False   False  False              False                   False
# ...          ...     ...    ...                ...                     ...
# 1995       False   False  False              False                   False
# 1996       False   False  False              False                   False
# 1997       False   False  False              False                   False
# 1998       False   False  False              False                   False
# 1999       False   False  False              False                   False
#
#       Work Experience  Family Size
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
df.max()
# Out:
# CustomerID                  2000
# Gender                      Male
# Age                           99
# Annual Income ($)         189974
# Spending Score (1-100)       100
# Work Experience               17
# Family Size                    9
# dtype: object

# %%
df.min()
# Out:
# CustomerID                     1
# Gender                    Female
# Age                            0
# Annual Income ($)              0
# Spending Score (1-100)         0
# Work Experience                0
# Family Size                    1
# dtype: object

# %%
df.corr()
# Out:
# C:\Users\kenan\AppData\Local\Temp\ipykernel_11156\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         CustomerID       Age  Annual Income ($)  \
# CustomerID                1.000000  0.070700           0.328400
# Age                       0.070700  1.000000           0.021378
# Annual Income ($)         0.328400  0.021378           1.000000
# Spending Score (1-100)    0.018936 -0.041798           0.023299
# Work Experience           0.091574 -0.014319           0.089136
# Family Size               0.159655  0.038254           0.093005
#
#                         Spending Score (1-100)  Work Experience  Family Size
# CustomerID                            0.018936         0.091574     0.159655
# ...

# %%
df.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.hist(bins=30,figsize=(15,15))
plt.show()

# %%
card_apporal_df=pd.read_csv("C:\\Users\\kenan\\Downloads\\price.csv")
print(card_apporal_df.head(10))
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
# 5           6  Female   22              58000                      76
# 6           7  Female   35              31000                       6
# 7           8  Female   23              84000                      94
# 8           9    Male   64              97000                       3
# 9          10  Female   30              98000                      72
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# ...

# %%
sns.histplot(card_apporal_df.Age,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(12,7))
sns.kdeplot(data=card_apporal_df,x="Age",y="Annual Income ($)",fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income ($)'>

# %%
sns.pairplot(data=card_apporal_df[["Age","Work Experience"]],hue="Age")

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap="Greys")
plt.show()
# Out:
# C:\Users\kenan\AppData\Local\Temp\ipykernel_11156\3959780361.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="Greys")

# %% [markdown]
# SPLITTING THE DATA

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(['Age','Spending Score (1-100)','Gender'], axis=1)
Y=df["Family Size"]

# %%
X
# Out:
#       CustomerID  Annual Income ($)  Work Experience  Family Size
# 0              1              15000                1            4
# 1              2              35000                3            3
# 2              3              86000                1            1
# 3              4              59000                0            2
# 4              5              38000                2            6
# ...          ...                ...              ...          ...
# 1995        1996             184387                8            7
# 1996        1997              73158                7            7
# 1997        1998              90961                9            2
# 1998        1999             182109                7            2
# 1999        2000             110610                5            2
#
# [2000 rows x 4 columns]

# %%
Y
# Out:
# 0       4
# 1       3
# 2       1
# 3       2
# 4       6
#        ..
# 1995    7
# 1996    7
# 1997    2
# 1998    2
# 1999    2
# Name: Family Size, Length: 2000, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
training_data_prediction=model.predict(X_train)

# %%
Y_pred=model.predict(X_test)

# %%
Y_pred
# Out:
# array([4., 3., 4., 3., 4., 4., 5., 7., 2., 3., 4., 3., 7., 7., 4., 2., 3.,
#        2., 7., 5., 6., 7., 6., 1., 3., 3., 6., 3., 4., 4., 4., 1., 5., 6.,
#        5., 6., 3., 4., 4., 4., 2., 7., 1., 4., 7., 2., 5., 5., 2., 7., 5.,
#        2., 1., 4., 7., 2., 6., 6., 7., 2., 4., 2., 4., 3., 1., 5., 2., 1.,
#        1., 3., 1., 2., 5., 6., 6., 1., 4., 6., 5., 5., 2., 3., 4., 6., 1.,
#        5., 2., 6., 2., 7., 3., 7., 2., 2., 4., 1., 7., 7., 5., 7., 3., 2.,
#        1., 6., 2., 2., 5., 1., 6., 1., 3., 5., 4., 2., 6., 6., 2., 2., 1.,
#        4., 6., 3., 7., 7., 4., 3., 5., 1., 6., 1., 3., 6., 4., 2., 4., 5.,
#        2., 4., 3., 6., 4., 2., 4., 7., 2., 7., 3., 3., 4., 3., 5., 4., 1.,
#        3., 2., 5., 3., 1., 2., 7., 3., 5., 3., 1., 6., 4., 7., 3., 1., 2.,
#        2., 7., 1., 2., 4., 2., 4., 7., 2., 6., 7., 6., 5., 6., 7., 6., 3.,
#        1., 4., 3., 7., 4., 1., 4., 1., 4., 5., 1., 4., 7., 6., 3., 2., 3.,
# ...

# %%
sns.regplot(x=Y_test,y=Y_pred,data=df,scatter_kws={"color":"green"},line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='Family Size'>
